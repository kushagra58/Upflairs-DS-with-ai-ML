# %% [markdown]
# # Data Science with AI/ML – NumPy Assignment
#
# **45 Days Summer Training Program**
#
# This notebook contains complete answers to all the questions from the provided assignment.

# %% [markdown]
# ## 1. Explain NumPy and its importance in Data Science and Machine Learning
#
# **NumPy (Numerical Python)** is a powerful Python library used for numerical and scientific computing. It provides support for multi-dimensional arrays and matrices, along with a large collection of mathematical functions to perform operations efficiently.
#
# ### Importance in Data Science and Machine Learning
# - Fast and memory-efficient array operations.
# - Supports multi-dimensional arrays and matrices.
# - Provides mathematical, statistical, and linear algebra functions.
# - Forms the foundation for libraries such as Pandas, SciPy, Matplotlib, and Scikit-learn.
# - Simplifies data preprocessing and manipulation tasks in ML workflows.

# %% [markdown]
# ## 2. Difference between Python Lists and NumPy Arrays
#
# | Feature | Python List | NumPy Array |
# |----------|------------|-------------|
# | Data Type | Can store different data types | Usually stores same data type |
# | Speed | Slower | Faster due to optimized C implementation |
# | Memory Usage | More | Less |
# | Mathematical Operations | Require loops | Vectorized operations |
# | Multi-dimensional Support | Limited | Excellent |
#
# ### Example
# ```python
# # Python List
# a = [1, 2, 3]
# b = [4, 5, 6]
# print(a + b)
#
# # NumPy Array
# import numpy as np
# x = np.array([1, 2, 3])
# y = np.array([4, 5, 6])
# print(x + y)
# ```

# %% [markdown]
# ## 3. NumPy Program

# %%
import numpy as np
arr = np.arange(1, 11)
print("1D Array:", arr)
matrix = np.arange(1, 10).reshape(3, 3)
print("\n3x3 Matrix:\n", matrix)
print("\nMatrix + Matrix:")
print(matrix + matrix)
print("\nMatrix * Matrix:")
print(matrix * matrix)
reshaped = arr.reshape(2, 5)
print("\nReshaped Array (2x5):")
print(reshaped)

# %% [markdown]
# ## 4. Statistics using NumPy

# %%
import numpy as np

marks = np.array([45, 56, 67, 78, 89])

print("Marks:", marks)
print("Mean:", np.mean(marks))
print("Median:", np.median(marks))
print("Standard Deviation:", np.std(marks))
print("Maximum:", np.max(marks))
print("Minimum:", np.min(marks))
print("Sorted Array:", np.sort(marks))

# %% [markdown]
# ## 5. Array Indexing, Slicing, and Boolean Masking

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50, 60, 70, 80])
print("First 4 elements:", arr[:4])
print("Alternate elements:", arr[::2])
print("Reversed array:", arr[::-1])
modified = arr.copy()
modified[modified > 50] = 0
print("Modified array:", modified)
