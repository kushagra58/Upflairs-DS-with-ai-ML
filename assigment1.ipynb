# %%
name = "Kushagra"
course = "B.Tech CSE"
age = 20
city = "Jaipur"
print("----- Student Details -----")
print(f"Name   : {name}")
print(f"Course : {course}")
print(f"Age    : {age}")
print(f"City   : {city}")
# Out:
# ----- Student Details -----
# Name   : Kushagra
# Course : B.Tech CSE
# Age    : 20
# City   : Jaipur

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
print(f"Hello, {name}, You are {age} years old.")
# Out:
# Hello, kushagra, You are 20 years old.

# %%
str="hello1"
print("Original string is:",str)
rev_str=str[::-1]
print("Reverse string is:",rev_str)
count=len(str)
print("Total characters in string is:", count)
# Out:
# Original string is: hello1
# Reverse string is: 1olleh
# Total characters in string is: 6

# %%
numbers = {1, 2, 3, 4, 2, 1, 5}
print("Original Set:", numbers)
numbers.add(10)
print("After Adding 10:", numbers)
numbers.remove(3)
print("After Removing 3:", numbers)
# Out:
# Original Set: {1, 2, 3, 4, 5}
# After Adding 10: {1, 2, 3, 4, 5, 10}
# After Removing 3: {1, 2, 4, 5, 10}

# %%
numbers = (10, 20, 30, 40, 20, 50,15)
print("Maximum Number in the tuple:", max(numbers))
print("Minimum Number in the tuple:", min(numbers))
print("20 appears in the tuple", numbers.count(20), "times")
print("Index of 40 is in the tuple:", numbers.index(40))
# Out:
# Maximum Number in the tuple: 50
# Minimum Number in the tuple: 10
# 20 appears in the tuple 2 times
# Index of 40 is in the tuple: 3
