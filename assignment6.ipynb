# %% [markdown]
# # Assignment 6 - OOPs and Regex

# %% [markdown]
# ## Q1. Employee Class

# %%
class Employee:
    def __init__(self, emp_name, emp_id, salary):
        self.emp_name = emp_name
        self.emp_id = emp_id
        self.salary = salary

    def display(self):
        print(f'Name: {self.emp_name}, ID: {self.emp_id}, Salary: {self.salary}')

e1 = Employee('Raj', 101, 50000)
e2 = Employee('Amit', 102, 60000)
e3 = Employee('Neha', 103, 55000)

e1.display()
e2.display()
e3.display()
# Out:
# Name: Raj, ID: 101, Salary: 50000
# Name: Amit, ID: 102, Salary: 60000
# Name: Neha, ID: 103, Salary: 55000

# %% [markdown]
# ## Q2. Calculator Class

# %%
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b != 0:
            return a / b
        return 'Division by zero not allowed'

calc = Calculator()
print('Addition:', calc.add(10, 5))
print('Subtraction:', calc.subtract(10, 5))
print('Multiplication:', calc.multiply(10, 5))
print('Division:', calc.divide(10, 5))
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %% [markdown]
# ## Q3. Book Class with Constructor

# %%
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display(self):
        print('Title:', self.title)
        print('Author:', self.author)
        print('Price:', self.price)

book = Book('Python Programming', 'Guido van Rossum', 499)
book.display()
# Out:
# Title: Python Programming
# Author: Guido van Rossum
# Price: 499

# %% [markdown]
# ## Q4. Vehicle and Car Inheritance

# %%
class Vehicle:
    def display(self):
        print('This is a Vehicle')

class Car(Vehicle):
    pass

c = Car()
c.display()
# Out:
# This is a Vehicle

# %% [markdown]
# ## Q5. Regex - Find All Digits

# %%
import re

text = 'Python123Assignment456'
digits = re.findall(r'\d+', text)
print('Digits found:', digits)
# Out:
# Digits found: ['123', '456']
