# %%
correct_pin = 6023
pin = int(input("Enter PIN: "))

if pin != correct_pin:
    print("Incorrect PIN")
else:
    balance = float(input("Enter Account Balance: "))
    withdraw = float(input("Enter Withdrawal Amount: "))

    if withdraw % 100 != 0:
        print("Invalid amount. Amount must be multiple of 100.")
    elif withdraw > balance:
        print("Insufficient balance")
    else:
        balance -= withdraw
        print("Withdrawal Successful")
        print("Remaining Balance =", balance)

# %%
year = int(input("Enter Year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a Leap Year")
    leap = True
else:
    print(year, "is not a Leap Year")
    leap = False

month = int(input("Enter Month (1-12): "))

if month in [1, 3, 5, 7, 8, 10, 12]:
    print("Total Days = 31")
elif month in [4, 6, 9, 11]:
    print("Total Days = 30")
elif month == 2:
    if leap:
        print("Total Days = 29")
    else:
        print("Total Days = 28")
else:
    print("Invalid Month")

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)

if num2 != 0:
    print("Division:", num1 / num2)
    print("Modulus:", num1 % num2)
else:
    print("Error: Division by zero")

# %%
square = [x**2 for x in range(1, 21)]
print("Squares:", square)

even_square = [x**2 for x in range(1, 21) if x % 2 == 0]
print("Even Squares:", even_square)

# %%
student = {
    "kushagra": 85,
    "nikhil": 90,
    "OM": 95,
    "anupam": 80,
    "yogesh": 88
}

print("Student Names:")
for name in student.keys():
    print(name)

print("Marks of OM:", student["OM"])
print("Highest Marks Student:", max(student, key=student.get))

student["vishnu"] = 92
print(student)

# %%
student = {
    "name": "kushagra",
    "age": 20,
    "course": "DS with Python"
}

numbers = {10, 20, 25, 30, 35}

num_str = input("Enter a number: ")
num = int(num_str)

print("Student Details:")
for key, value in student.items():
    print(f"{key}: {value}")

print("Numbers in set:", numbers)
print("String value:", num_str)
print("String type:", type(num_str))
print("Integer value:", num)
print("Integer type:", type(num))
